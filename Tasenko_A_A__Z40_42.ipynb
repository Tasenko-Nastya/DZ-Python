# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasenko-Nastya/DZ-Python/blob/main/Tasenko_A_A__Z40_42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv', sep=',')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dropna(inplace=True)
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
df.tail(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df[['median_house_value','population']]
# Out:
#        median_house_value  population
# 0                 66900.0      1015.0
# 1                 80100.0      1129.0
# 2                 85700.0       333.0
# 3                 73400.0       515.0
# 4                 65500.0       624.0
# ...                   ...         ...
# 16995            111400.0       907.0
# 16996             79000.0      1194.0
# 16997            103600.0      1244.0
# 16998             85800.0      1298.0
# 16999             94600.0       806.0
#
# [17000 rows x 2 columns]

# %%
df[df['population'] < 500]['median_house_value'].mean()
# Out:
# 206683.83635227982

# %% [markdown]
#  Узнать какая максимальная households в зоне минимального значения population.

# %%
df[['households','population']]
# Out:
#        households  population
# 0           472.0      1015.0
# 1           463.0      1129.0
# 2           117.0       333.0
# 3           226.0       515.0
# 4           262.0       624.0
# ...           ...         ...
# 16995       369.0       907.0
# 16996       465.0      1194.0
# 16997       456.0      1244.0
# 16998       478.0      1298.0
# 16999       270.0       806.0
#
# [17000 rows x 2 columns]

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0
